# %% [markdown]
# **HOW TO SAVE FIGURE**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

# %%
plt.pie([10,20,30])
plt.savefig("/Users/pritamsaha/Downloads/subplot_figure.png")
plt.savefig("pie_chart",dpi=1000,facecolor="g")
plt.show()
